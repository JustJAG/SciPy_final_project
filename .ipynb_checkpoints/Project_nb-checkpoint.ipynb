# %% [markdown]
# # Final Project for DNDS6288 - Scientific Python 2021/22 Fall
# ## Student: Abay Jumabayev
# ## [GitHub link](https://github.com/JustJAG/SciPy_final_project)
# ## 1. Introduction
# I want to accomplish two things:
# 1. Assess the simple trading algorithm efficiency
# 2. Predict the future stock prices of stocks
#
# I will start with the description of the trading algorithm. The idea is to buy stock, hold them until the stock prices increases by $x$ percent, sell, and receive profits. Buy stock again if the price drops by $x$ percent from the moment of last transaction. Repeat this process again and again.
#
# I need a stock with a volatile price for this algorithm to work. In this project, I will use Tesla (TSLA ticker) as it is trending and volatile. The stock under analysis can be changed in the code.
#
# Testing period is 1 year (which can be changed in the code). The data is the hourly data from Yahoo Finance.
#
# I will compare the effectiveness of the algorithm with the S&P 500 ETF Trust (SPY ticker), which is considered to be a good option for beginning investors who don't want to interact with the stocks much.
#
# Problem: Suppose an investor has 1000\$ and 1 year. Base option is to buy S&P 500 ETF Trust. The second option is to use an algorithm described above.

# %% [markdown]
# ## 2. Getting and cleaning data
# Importing necessary modules

# %%
import pandas as pd
import numpy as np
import random as rnd
import scipy.stats as stats
import scipy.optimize as opt
import json as json
import matplotlib as mpl
from math import exp
from matplotlib import pyplot as plt
from matplotlib.dates import DateFormatter, MonthLocator
from matplotlib.lines import Line2D
from IPython.core.pylabtools import figsize
from IPython.display import display
from IPython.core.display import HTML

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout
rnd.seed(2)
import warnings
warnings.filterwarnings('ignore')
import yfinance as yf

# %% [markdown]
# Choosing base and volatile stocks, choosing period and interval of analysis

# %%
# Choosing tickers for an analysis
base_ticker = "SPY"
algo_ticker = "TSLA"

# Choosing period of analysis and interval
period = "1y" # 1 year
interval = "60m" # 1 hour

# %% [markdown]
# Getting the data. Both SPY and TSLA separately

# %%
# # UNCOMMENT THIS TO DOWNLOAD THE DATA
# # Get the data
# base = yf.download(tickers=base_ticker, period=period, interval=interval)
# algo = yf.download(tickers=algo_ticker, period=period, interval=interval)

# %% [markdown]
# Save the raw data. We might need it for reproducability. I saved the data I downloaded on [github](https://github.com/JustJAG/SciPy_final_project)
#
# First, define the folders

# %%
cd
# Out:
# C:\Users\77774

# %%
# location folders
data_in = ".\\Documents\\GitHub\\SciPy_final_project\\raw\\"
data_out = ".\\Documents\\GitHub\\SciPy_final_project\\clean\\"
results = ".\\Documents\\GitHub\\SciPy_final_project\\results\\"

# %%
# # UNCOMMENT THIS TO SAVE THE DATA
# # save raw data
# base.to_csv(data_in+'base_raw.csv',index=True)
# algo.to_csv(data_in+'algo_raw.csv',index=True)

# %% [markdown]
# For now, I will use the saved data. If you want to download the data from scratch, uncomment two cells above.

# %%
base = pd.read_csv(data_in+'base_raw.csv')
algo = pd.read_csv(data_in+'algo_raw.csv')

# %%
# convert Datetime column from string to datetime and change format
def clean_dates(df):
    df.Datetime = df.Datetime.map(lambda x: str(x)[:-6])
    df.Datetime = pd.to_datetime(df.Datetime, format = '%Y-%m-%d %H:%M:%S')
    return df
    
base = clean_dates(base)
algo = clean_dates(algo)

# %% [markdown]
# Let's draw the returns of these two tickers

# %%
# create fig, axes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,7)) 

# first plot of Base
axes[0].plot(base.Datetime, base['Adj Close'], linewidth=3, color = 'green')
axes[0].set_ylabel('$')
axes[0].set_title('S&P 500 ETF Trust')

months = MonthLocator()
monthsFmt = DateFormatter("%b")
axes[0].xaxis.set_major_locator(months)
axes[0].xaxis.set_major_formatter(monthsFmt)

# second plot of Algo
axes[1].plot(algo.Datetime, algo['Adj Close'], linewidth=3, color = 'green')
axes[1].set_ylabel('$')
axes[1].set_title('Tesla, Inc. (TSLA)')

months = MonthLocator()
monthsFmt = DateFormatter("%b")
axes[1].xaxis.set_major_locator(months)
axes[1].xaxis.set_major_formatter(monthsFmt)

# %% [markdown]
# We can clearly see that SPY grows steadily while TSLA has some volatility.

# %% [markdown]
# ## 3. Creating and assessing the algorithm
#
# Below is a simple algorithm function. A function takes dataframe, prices, and threshold as an input. The dataframe is the volatile stock df we downloaded (algo), price is the stock price (*Adj close* column of the dataframe), and the threshold is the \% change threshold ($x$ from the description above).
#
# The function will add three columns to the dataframe: *buy*, *sell*, and *returns*. *buy* and *sell* are the actions of buying or selling stocks (=1 if buy/sell, =0 otherwise). *returns* will give the cumulative returns.

# %%
def algorithm(df, stock_price, threshold):
    ### creating a list of actions
    buy_actions = [0] * len(stock_price)
    sell_actions = [0] * len(stock_price)
    
    ### add necessary variables
    pos = 0
    last_action = "Sell"
    
    ### loop through all prices
    for i in range(1,len(stock_price)):
        
        # algorithm takes the first price of the year and compares it to the subsequent prices
        checkpoint = stock_price[pos]
        
        # if price drops by x percent, buy the stock
        if last_action == "Sell":
            if (stock_price[i]-checkpoint)/checkpoint < -threshold:
                pos = i
                buy_actions[i] = 1
                last_action = "Buy"
        # if price increases by x percent, sell the stock        
        else:
            if (stock_price[i]-checkpoint)/checkpoint > threshold:
                pos = i
                sell_actions[i] = 1
                last_action = "Sell"
                
    ### add buy and sell columns to the dataframe
    df['buy_' + str(threshold)] = buy_actions
    df['sell_' + str(threshold)] = sell_actions
    
    ### add returns column to the dataframe
    df['returns_' + str(threshold)] = 1

    # create a temporary df that will calculate the returns
    df_temp = df.loc[(df['buy_' + str(threshold)] == 1) | (df['sell_' + str(threshold)] == 1)]
    # calculate percentage change from each buy-sell operation
    df_temp['percent'] = df_temp['Adj Close'].pct_change()
    df_temp = df_temp.loc[(df['sell_' + str(threshold)] == 1)]
    # calculate returns
    returns = [0]*len(df_temp['percent'])
    returns[0]=1+df_temp['percent'].iloc[0]
    for i in range(1, len(df_temp['percent'])):
        returns[i]=returns[i-1]*(1+df_temp['percent'].iloc[i])
    df_temp['returns'] = returns
    df_temp = df_temp.reset_index()
    df_temp = df_temp[["index","returns"]]
    
    # add returns column to the dataframe
    for i in range(len(df_temp)):
        df.loc[df_temp['index'].iloc[i]:, 'returns_' + str(threshold)] = df_temp.returns.iloc[i]

# %% [markdown]
# Run the algorithm with four different threshold values
#
# I chose 1%, 3%, 5%, and 10%

# %%
thresholds = [0.01,0.03,0.05,0.1]
for i in thresholds:
    algorithm(algo,algo['Adj Close'], threshold=i)

# %% [markdown]
# Let's see the returns of the algorithm

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,12)) 
plt.suptitle('Returns of algorithms with different thresholds')
for plt, i in zip(axes.reshape(-1), thresholds):
    buy_df = algo[(algo['buy_'+str(i)]==1)]
    sell_df = algo[(algo['sell_'+str(i)]==1)]    
    
    plt.scatter(buy_df['Datetime'], buy_df['returns_'+str(i)],linestyle="solid", c = "green")
    plt.scatter(sell_df['Datetime'], sell_df['returns_'+str(i)],linestyle="solid", c = 'red')
    plt.plot(algo.Datetime,algo['returns_'+str(i)],c = "gray", alpha = 0.8)    
    
    # x axis as month names
    months = MonthLocator()
    monthsFmt = DateFormatter("%b")
    plt.xaxis.set_major_locator(months)
    plt.xaxis.set_major_formatter(monthsFmt)
    
    # Create legends
    legend_elements = [Line2D([0], [0], color='gray', lw=4, label='Returns'),
                       Line2D([0], [0], marker='o', color='green', label='Buy decision',
                              markerfacecolor='g', markersize=10),
                       Line2D([0], [0], marker='o', color='red', label='Sell decision',
                              markerfacecolor='r', markersize=10)]
    plt.legend(handles=legend_elements)
    
    # set title
    plt.set_title('Threshold = '+str(i))
    # set y label
    plt.set_ylabel('Returns')
    plt.set_ylim([0.9, 1.6])

# %% [markdown]
# As we can see, the higher the threshold, the less operations there will be. Moreover, the higher the threshold, the less returns one can get out of the algorithm trading.
#
# By far, the best performance is achieved with a threshold of 0.01. Let's assess it's performance on a price graph:

# %%
from matplotlib import pyplot as plt
buy_df = algo[(algo['buy_0.01']==1)]
sell_df = algo[(algo['sell_0.01']==1)]    

# create fig, axes
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14,7)) 

axes.scatter(buy_df['Datetime'], buy_df['Adj Close'],linestyle="solid", c = "green", marker = 6)
axes.scatter(sell_df['Datetime'], sell_df['Adj Close'],linestyle="solid", c = 'red', marker = 7)
axes.plot(algo.Datetime,algo['Adj Close'],c = "gray", alpha = 0.8)    

# x axis as month names
months = MonthLocator()
monthsFmt = DateFormatter("%b")
axes.xaxis.set_major_locator(months)
axes.xaxis.set_major_formatter(monthsFmt)

# Create legends
legend_elements = [Line2D([0], [0], color='gray', lw=2, label='Price'),
                   Line2D([0], [0], marker=10, color='green', label='Buy decision',
                          markerfacecolor='g', markersize=10, linestyle = 'None',),
                   Line2D([0], [0], marker=7, color='red', label='Sell decision',
                          markerfacecolor='r', markersize=10, linestyle = 'None',)]
axes.legend(handles=legend_elements)

# set title
axes.set_title('TSLA price and algorithm decisions')
# set y label
axes.yaxis.set_major_formatter('${x:1.0f}')

# %% [markdown]
# We can see that although the returns were high (55% (!) for 1 year), the algorithm performs poorly in general. The thing is that it buys and sells stocks almost at the same range. For example, if the buy decision was made at 100, sell would happen at 101. The next buy decision will be at 99.99 (101-1% = 99.99) and so on. The decisions will be made around 100 price.
#
# We were lucky that TSLA behaved that way and was fluctuating around one price. If the stock price would be always growing or always falling, then the algorithm wouldn't make any decisions. As we can see, after September, when price grew rapidly, algorithm stopped working because of the increased stock price
#
# One suggestion to improve the algorithm could be an inclusion of growth into an algorithm. I could use different thresholds for buying and selling decisions. I will left this as an exercise for a reader.
#
# For now, I want to compare how the algorithm performed against the base ticker (SPY) and the TSLA itself. According to the graph, TSLA ticker could have higher returns than the one of the algorithm.

# %%
# function to add returns column to a df
def calculate_returns(df):
    df['dodreturn'] = df['Adj Close'].pct_change()
    returns = [0]*len(df)
    returns[0]=1
    for i in range(1, len(df)):
        returns[i]=returns[i-1]*(1+df['dodreturn'].iloc[i])
    df['returns'] = returns

# %%
# calculate returns for base and algo tickers
calculate_returns(base)
calculate_returns(algo)

# %%
# create fig, axes
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14,7)) 

axes.plot(algo.Datetime,algo['returns'],c = "blue", alpha = 0.8)    
axes.plot(base.Datetime,base['returns'],c = "brown", alpha = 0.8)    
axes.plot(algo.Datetime,algo['returns_0.01'],c = "green", alpha = 0.8)    

# x axis as month names
months = MonthLocator()
monthsFmt = DateFormatter("%b")
axes.xaxis.set_major_locator(months)
axes.xaxis.set_major_formatter(monthsFmt)

# Create legends
legend_elements = [Line2D([0], [0], color='blue', lw=2, label='TSLA returns'),
                   Line2D([0], [0], color='brown', lw=2, label='SPY returns'),
                   Line2D([0], [0], color='green', lw=2, label='Algorithm returns'),]
axes.legend(handles=legend_elements)

# set title
axes.set_title('Returns of base ticker, alternative tickers, and algorithm')
# Out:
# Text(0.5, 1.0, 'Returns of base ticker, alternative tickers, and algorithm')

# %% [markdown]
# The algorithm's performance was good (maybe we got lucky this time), but not the best one. TSLA itself had high returns, so buying TSLA a year ago and selling it now would bring about 65% of returns.
#
# Nevertheless, throughout a year, algorithm's strategy provided highest returns among the three strategies.
#
# ## 4. Predicting price
#
# Now I want to predict the price of TSLA ticker using only historical prices

# %%
# copy a separate df, keep only price values
df = algo
df = df['Adj Close'].values
df = df.reshape(-1, 1)

# split the data into training and testing sets:
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])

# %% [markdown]
# I scale the data first, all the values will be from 0 to 1.

# %%
# scale data
scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

# %% [markdown]
# Now comes the function create_dataset, which creates the dataset.
#
# The dependent variable is the price. The independent variables are the prices. There are 7 prices in a day, and I will use last 14 days for analysis (hence, 98 in the function below). So, I will try to predict the price based on the prices of last two weeks.

# %%
def create_dataset(df):
    # independent variable
    x = []
    # dependent variable
    y = []
    for i in range(98, df.shape[0]):
        x.append(df[i-98:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return x,y

# %%
# create x_train, y_train, x_test, y_test
x_train, y_train = create_dataset(dataset_train)
x_test, y_test = create_dataset(dataset_test)

# %%
# creating the model
model = Sequential()
model.add(LSTM(units=96, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# Start training the model
#
# Then saving the model

# %%
model.fit(x_train, y_train, epochs=30, batch_size=32)
model.save(results+'stock_prediction.h5')
# Out:
# Epoch 1/30
# 41/41 [==============================] - 27s 157ms/step - loss: 0.0619
# Epoch 2/30
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0076
# Epoch 3/30
# 41/41 [==============================] - 6s 140ms/step - loss: 0.0064
# Epoch 4/30
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0059
# Epoch 5/30
# 41/41 [==============================] - 7s 160ms/step - loss: 0.0065
# Epoch 6/30
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0052
# Epoch 7/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0045
# Epoch 8/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0041
# Epoch 9/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0043
# Epoch 10/30
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0043
# Epoch 11/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0039
# Epoch 12/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0036
# Epoch 13/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0035
# Epoch 14/30
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0034
# Epoch 15/30
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0029
# Epoch 16/30
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0030
# Epoch 17/30
# 41/41 [==============================] - 6s 142ms/step - loss: 0.0034
# Epoch 18/30
# 41/41 [==============================] - 6s 139ms/step - loss: 0.0029
# Epoch 19/30
# 41/41 [==============================] - 6s 143ms/step - loss: 0.0027
# Epoch 20/30
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0030
# Epoch 21/30
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0029
# Epoch 22/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0025
# Epoch 23/30
# 41/41 [==============================] - 6s 134ms/step - loss: 0.0031
# Epoch 24/30
# 41/41 [==============================] - 6s 137ms/step - loss: 0.0023
# Epoch 25/30
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0022
# Epoch 26/30
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0025
# Epoch 27/30
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0022
# Epoch 28/30
# 41/41 [==============================] - 6s 136ms/step - loss: 0.0025
# Epoch 29/30
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0021
# Epoch 30/30
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0021

# %%
model = load_model(results+'stock_prediction.h5')

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))
algo_tail = algo.tail(len(y_test_scaled))

fig, ax = plt.subplots(figsize=(14,7))

ax.plot(algo_tail.Datetime, y_test_scaled, color='red', label='Original price')
ax.plot(algo_tail.Datetime, predictions, color='blue', label='Predicted price')
plt.legend()
# x axis as month names
months = MonthLocator()
monthsFmt = DateFormatter("%b")
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(monthsFmt)

# set title
ax.set_title('Actual and predicted price of TSLA')
# set y label
ax.yaxis.set_major_formatter('${x:1.0f}')

# %% [markdown]
# Prediction was good.

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))
algo_tail = algo.tail(len(y_test_scaled))

fig, ax = plt.subplots(figsize=(14,7))

ax.plot(y_test_scaled, color='red', label='Original price')
ax.plot(predictions, color='blue', label='Predicted price')
plt.legend()


# set title
ax.set_title('Actual and predicted price of TSLA')
# set y label
ax.yaxis.set_major_formatter('${x:1.0f}')
